# %%
import numpy as np
import pandas as pd

# %%
sbs18_df = pd.read_csv('NFCS 2018 State Data 190603.csv', delimiter = ',')

# %%
sbs18_df.head()
# Out:
#        NFCSID  STATEQ  CENSUSDIV  CENSUSREG  A3  A3Ar_w  A3B  A4A_new_w  \
# 0  2018010001      48          9          4   2       5   11          1
# 1  2018010002      10          5          3   2       2    8          1
# 2  2018010003      44          7          3   2       2    8          1
# 3  2018010004      10          5          3   2       1    7          1
# 4  2018010005      13          8          4   1       2    2          1
#
#    A5_2015  A6    ...     M42  M6  M7  M8  M31  M9 M10    wgt_n2    wgt_d2  \
# 0        5   4    ...           1   3  98   98  98   1  0.683683  0.519642
# 1        6   1    ...           1   3  98    3   1  98  0.808358  2.516841
# 2        6   1    ...           1   1  98   98   1  98  1.021551  1.896192
# 3        6   2    ...       7  98  98   4    4   2  98  0.808358  2.516841
# 4        6   1    ...           1   3  98    2   1  98  0.448075  0.614733
#
#      wgt_s3
# 0  1.095189
# 1  0.922693
# 2  0.671093
# 3  0.922693
# 4  1.232221
# ...

# %%
sbs18_df.shape
# Out:
# (27091, 128)

# %%
sbs18_df.columns
# Out:
# Index(['NFCSID', 'STATEQ', 'CENSUSDIV', 'CENSUSREG', 'A3', 'A3Ar_w', 'A3B',
#        'A4A_new_w', 'A5_2015', 'A6',
#        ...
#        'M42', 'M6', 'M7', 'M8', 'M31', 'M9', 'M10', 'wgt_n2', 'wgt_d2',
#        'wgt_s3'],
#       dtype='object', length=128)

# %%
sbs18_df.isnull().sum()
# Out:
# NFCSID        0
# STATEQ        0
# CENSUSDIV     0
# CENSUSREG     0
# A3            0
# A3Ar_w        0
# A3B           0
# A4A_new_w     0
# A5_2015       0
# A6            0
# A7            0
# A7A           0
# A11           0
# A8            0
# AM21          0
# AM30          0
# AM31          0
# AM22          0
# X3            0
# X4            0
# A9            0
# A40           0
# A10           0
# A10A          0
# A21_2015      0
# A22_2015      0
# A14           0
# A41           0
# J1            0
# J2            0
#              ..
# G25_2         0
# G25_3         0
# G25_4         0
# G25_5         0
# G38           0
# G23           0
# H1            0
# H30_1         0
# H30_2         0
# H30_3         0
# M1_1          0
# M1_2          0
# M4            0
# M40           0
# M20           0
# M21_1         0
# M21_2_2015    0
# M21_3         0
# M21_4         0
# M41           0
# M42           0
# M6            0
# M7            0
# M8            0
# ...

# %%
sbs18_df['A4A_new_w'].unique()
# Out:
# array([1, 2])

# %%
sbs18_df['A8'].describe()
# Out:
# count    27091.000000
# mean         4.479384
# std          2.072720
# min          1.000000
# 25%          3.000000
# 50%          5.000000
# 75%          6.000000
# max          8.000000
# Name: A8, dtype: float64

# %%
sbs18_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27091 entries, 0 to 27090
# Columns: 128 entries, NFCSID to wgt_s3
# dtypes: float64(3), int64(84), object(41)
# memory usage: 26.5+ MB

# %%
#sbs18_df.dtypes

# %%
sbs18_df.select_dtypes('float64')
# Out:
#          wgt_n2    wgt_d2    wgt_s3
# 0      0.683683  0.519642  1.095189
# 1      0.808358  2.516841  0.922693
# 2      1.021551  1.896192  0.671093
# 3      0.808358  2.516841  0.922693
# 4      0.448075  0.614733  1.232221
# 5      1.017910  1.329637  0.936126
# 6      1.433500  1.479585  1.020436
# 7      0.445837  1.745104  0.931951
# 8      1.138393  0.799081  0.761420
# 9      0.946931  2.789539  1.028050
# 10     0.445837  0.545928  0.772342
# 11     0.815116  1.202140  0.793922
# 12     0.946931  2.789539  1.028050
# 13     0.364344  2.319732  0.903927
# 14     2.219286  0.689065  1.056319
# 15     1.026420  0.654446  0.872951
# 16     1.259369  1.208025  1.045329
# 17     0.522265  1.833441  1.007209
# 18     1.504502  0.737499  0.860371
# 19     1.192406  0.273704  1.131038
# 20     1.506887  2.937645  1.096984
# 21     2.219286  0.984061  1.045602
# 22     0.980497  2.786506  1.013312
# 23     2.219286  1.532573  1.096985
# 24     1.026420  2.746374  0.909018
# ...

# %%
sbs18_df.select_dtypes('int64')
# Out:
#            NFCSID  STATEQ  CENSUSDIV  CENSUSREG  A3  A3Ar_w  A3B  A4A_new_w  \
# 0      2018010001      48          9          4   2       5   11          1
# 1      2018010002      10          5          3   2       2    8          1
# 2      2018010003      44          7          3   2       2    8          1
# 3      2018010004      10          5          3   2       1    7          1
# 4      2018010005      13          8          4   1       2    2          1
# 5      2018010006      11          5          3   2       2    8          1
# 6      2018010007      11          5          3   1       2    2          1
# 7      2018010008      26          4          2   2       1    7          1
# 8      2018010009      21          5          3   1       2    2          1
# 9      2018010010      10          5          3   2       6   12          1
# 10     2018010011      28          4          2   2       2    8          1
# ...

# %%
sbs18_df.select_dtypes('object').isnull().sum()
# Out:
# AM30          0
# AM31          0
# AM22          0
# X4            0
# A10           0
# A21_2015      0
# A22_2015      0
# A14           0
# J6            0
# J8            0
# J9            0
# B4            0
# B41_1         0
# B41_2         0
# C2_2012       0
# C3_2012       0
# C5_2012       0
# C10_2012      0
# C11_2012      0
# B14           0
# E7            0
# E8            0
# E20           0
# E15_2015      0
# F2_1          0
# F2_2          0
# F2_3          0
# F2_4          0
# F2_5          0
# F2_6          0
# F10           0
# G33           0
# G35           0
# G22_2015      0
# G40           0
# M21_1         0
# M21_2_2015    0
# M21_3         0
# M21_4         0
# M41           0
# M42           0
# dtype: int64
